# %% [markdown]
# # Part 2: Problem Statement, EDA and Dataset ( Wednesday July 8th, 2020)
#
# Necessary Deliverables / Submission
#
# Materials must be presented in a Jupyter Notebook stored within a repository on your personal (not GA) GitHub. Please submit a link to this repository by the due date (submission link).
#
# <hr>
#
# ### Project Chosen
#
# My project will be revenue prediction model on video gaming and doing analysis on which gaming platform  generates the most revenue.
#
# I will using SARIMA time-series prediction model in predicting the revenue, model performance will be guided by Mean Square Error. The model should at least improve upon baseline by 10%. Baseline is defined as the revenue generated from Xbox, Playstation and Nintendo from 2008 - 2018.
#
# The game developers will be interested in my prediction so that they can better understand how much revenue can be generated through various gaming platform and set a suitable amount of budget for future game developement.
#
# <hr>
#
#
# ### Problem statement
#
# With the rise of mobile games gaining overall market share for gaming industry for around 3% - 7% per year since 2012, the video gaming industry has undergo a decrease in market share especially when there are more free-to-play mobile games which is attracting alot of gamers to play them and switch over.
#
# Through my prediction model for overall gaming revenues (excluding mobile games), game developers to understand how much is the possible revenue for the video game industry in the future years and set aside the right budget for developing games in order not to go bust.
#
# Additionally, by identifying which are the top revenue generating platforms between Xbox, Playstation and Nintendo, game developers can explore the possiblity of developing games that involves cross-platform gaming such as Call of Duty which is available on PC, PS4 and Xbox.
#
# <hr>
#
#
# ### Outline of EDA
#
# Think about the following as you perform your initial EDA.
# Identify the data types you are working with.
# Examine the distributions of your data, numerically and/or visually.
# Identify outliers.
# Identify missing data and look for patterns of missing data.
# Describe how your EDA will inform your modeling decisions and process.
#
#
# I will be performing EDA based on features like, the total sales of each game title, the most popular genre of games which has generate the most of the sales gobally, identifying which platforms gave the highest sale volume globally through visualisation and summarizing my preliminary findings through the dataset.
#
# <hr>
#
#
# ### Modeling to date
#
#
# Time-Series Prediction Model - SARIMA
#
# <hr>
#
#
# ### Goal of Predictive Model
#
# Revises initial goals & success criteria, as needed
#
# This goal of this predictive model is to provide an insight for game developers on what is the projected revenue for the video gaming industry (except mobile games) and also focus on the top gaming platforms that generates the most revenue.
#
# Model performance will be guided by Mean Square Error. The model should at least improve upon baseline by 10%
#
# With the predicted revenue from my model, game developer companies will be able to better manage their cost in games development and focus on the gaming platform they are targeting while minimising cost.
#
# <hr>
#
#
# ###  Data Used
#
# Data will be found on this website: https://www.vgchartz.com/gamedb/
# Scrapping data will be saved as .CSV files.
# There might be some missing values since this is an independent gaming website.
#
#
# The variables in the dataset are as follows:<br>
# Id - A unique ID for each game in the dataset
# NA_Sales - Game sales in North America (in millions of units)
# Platform - Console on which the game is running
# Year_of_Release - Year the game was released
# Genre - Game category
# Publisher - Publisher
# JP_Sales - Game sales in Japan (in millions of units)
# Critic_Score - Aggregate score compiled by Metacritic staff
# Critic_Count - The number of critics used in coming up with the Critic_score
# User_Score - Score by Metacritic's subscribers
# User_Count - Number of users who gave the user_score
# Developer - Party responsible for creating the game
# Rating - The ESRB ratings (E.g. Everyone, Teen, Adults Only, etc.)
#
# <hr>
#
# Reference:
# https://machinelearningmastery.com/time-series-forecasting-performance-measures-with-python/
# https://www.digitaltrends.com/gaming/all-cross-platform-games/
